# %% [markdown]
# <h1 align='center'>Regular Expression Exericse</h1>

# %%
import re

# %% [markdown]
# # Use [this guide](https://www.researchgate.net/publication/395016959_Regex_for_NLP_Guide) as reference

# %% [markdown]
# ## 1. Extract all hashtags from following text.
#
# A hashtag is the text that appears after # and is a single word. Also it contains only alpha numeric characters i.e. A-Z a-z , 0 to 9 and underscore _. It needs to start with a letter and be at least 3 characters long.

# %%
text = '''
@user #friend how are you? Don#t #Count #123456 but do #aA9_3z
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

# %% [markdown]
# ## 2. Extract elongations
#
# An elongation is a word that has a character repeated for effect. Like coooool, nooo. Don't include words that already have a repeating character if they don't repeat it extra times like 'cool', 'less'.

# %%
text = '''
Omg I’m soooo excited right now!!! I just got my coffeeee and it’s exactly what I needed after such a sleeepy morning. The barista was so sweet, they even wrote my name correctly (finallyyyy). Now I’m sitting in this cozy little corner, watching the rain fall slooowly down the window. It’s honestly the chillest vibe ever. Also, my friend just texted me “yessss let’s meet up later,” so it’s turning into a good day alreadyyy. Feeling reaaally grateful.
'''
pattern = '' # todo: type your regex here

re.findall(pattern, text)

with open('count_1w.txt') as words_file:
    dictionary = {word for word, _ in words_file}

# Filter out false positives

# %% [markdown]
# ## 3. Think of your own use case and implement a regex for it
